# %%
from tensorflow.keras.layers import Conv2D,Flatten,Dense,MaxPooling2D,Dropout,Activation
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt

# %%
train_dir = 'chest_xray/train/'
val_dir = 'chest_xray/val/'
test_dir = 'chest_xray/test'

# %%
batch_size = 16
epochs = 20
img_height,img_width = 150,150
nb_train_samples = 5217
nb_validation_samples = 17

# %%
train_datagen = ImageDataGenerator(rescale=1./255,
                                  shear_range=0.2,
                                  zoom_range=0.2,
                                  horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size=(img_height,img_width),
                                               batch_size=batch_size,
                                               class_mode='binary')

val_data = test_datagen.flow_from_directory(val_dir,
                                               target_size=(img_height,img_width),
                                               batch_size=batch_size,
                                               class_mode='binary')

test_data = test_datagen.flow_from_directory(test_dir,
                                               target_size=(img_height,img_width),
                                               batch_size=batch_size,
                                               class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.
# Found 16 images belonging to 2 classes.
# Found 624 images belonging to 2 classes.

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=(img_width,img_height,3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      896
#
#  activation (Activation)     (None, 148, 148, 32)      0
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 32)        9248
#
#  activation_1 (Activation)   (None, 72, 72, 32)        0
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 64)        18496
#
#  activation_2 (Activation)   (None, 34, 34, 64)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 18496)             0
#
#  dense (Dense)               (None, 64)                1183808
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
#  activation_4 (Activation)   (None, 1)                 0
#
# =================================================================
# Total params: 1,212,513
# Trainable params: 1,212,513
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy',
              metrics=['accuracy'],
              optimizer='rmsprop')

# %%
mc = ModelCheckpoint(
    'pnemonia_model_mc.h5',
    monitor="val_loss",
    verbose=1,
    save_best_only=False,
)

# %%
history = model.fit(train_data,
                  epochs=epochs,
                  steps_per_epoch = nb_train_samples//batch_size,
                  validation_data=val_data,
                  validation_steps=nb_validation_samples//batch_size,
                 )
model.save('pneumonia_model_full.h5')
# Out:
# Epoch 1/20
# 326/326 [==============================] - 138s 420ms/step - loss: 0.4493 - accuracy: 0.7979 - val_loss: 0.6665 - val_accuracy: 0.6875
# Epoch 2/20
# 326/326 [==============================] - 114s 351ms/step - loss: 0.2786 - accuracy: 0.8865 - val_loss: 0.8824 - val_accuracy: 0.6250
# Epoch 3/20
# 326/326 [==============================] - 118s 361ms/step - loss: 0.2465 - accuracy: 0.8997 - val_loss: 1.1278 - val_accuracy: 0.6875
# Epoch 4/20
# 326/326 [==============================] - 107s 327ms/step - loss: 0.2193 - accuracy: 0.9208 - val_loss: 0.8186 - val_accuracy: 0.7500
# Epoch 5/20
# 326/326 [==============================] - 107s 327ms/step - loss: 0.2014 - accuracy: 0.9283 - val_loss: 0.6701 - val_accuracy: 0.7500
# Epoch 6/20
# 326/326 [==============================] - 106s 326ms/step - loss: 0.1942 - accuracy: 0.9306 - val_loss: 0.8769 - val_accuracy: 0.7500
# Epoch 7/20
# 326/326 [==============================] - 107s 329ms/step - loss: 0.1790 - accuracy: 0.9302 - val_loss: 2.0000 - val_accuracy: 0.6250
# Epoch 8/20
# 326/326 [==============================] - 108s 331ms/step - loss: 0.1719 - accuracy: 0.9385 - val_loss: 0.6556 - val_accuracy: 0.8125
# Epoch 9/20
# 326/326 [==============================] - 112s 343ms/step - loss: 0.1720 - accuracy: 0.9415 - val_loss: 1.2443 - val_accuracy: 0.6250
# Epoch 10/20
# 326/326 [==============================] - 108s 330ms/step - loss: 0.1737 - accuracy: 0.9423 - val_loss: 0.3742 - val_accuracy: 0.8125
# Epoch 11/20
# 326/326 [==============================] - 107s 329ms/step - loss: 0.1509 - accuracy: 0.9490 - val_loss: 2.3068 - val_accuracy: 0.5625
# Epoch 12/20
# 326/326 [==============================] - 121s 370ms/step - loss: 0.1545 - accuracy: 0.9473 - val_loss: 0.2865 - val_accuracy: 0.8125
# Epoch 13/20
# 326/326 [==============================] - 121s 372ms/step - loss: 0.1483 - accuracy: 0.9479 - val_loss: 1.3412 - val_accuracy: 0.6250
# Epoch 14/20
# 326/326 [==============================] - 121s 372ms/step - loss: 0.1559 - accuracy: 0.9434 - val_loss: 1.6134 - val_accuracy: 0.6875
# Epoch 15/20
# 326/326 [==============================] - 120s 367ms/step - loss: 0.1442 - accuracy: 0.9507 - val_loss: 1.1962 - val_accuracy: 0.6875
# Epoch 16/20
# 326/326 [==============================] - 133s 408ms/step - loss: 0.1472 - accuracy: 0.9515 - val_loss: 0.6646 - val_accuracy: 0.7500
# Epoch 17/20
# 326/326 [==============================] - 135s 415ms/step - loss: 0.1366 - accuracy: 0.9509 - val_loss: 0.7287 - val_accuracy: 0.6875
# Epoch 18/20
# 326/326 [==============================] - 122s 376ms/step - loss: 0.1444 - accuracy: 0.9479 - val_loss: 1.5170 - val_accuracy: 0.6250
# Epoch 19/20
# 326/326 [==============================] - 115s 352ms/step - loss: 0.1468 - accuracy: 0.9475 - val_loss: 1.8790 - val_accuracy: 0.6250
# Epoch 20/20
# 326/326 [==============================] - 116s 357ms/step - loss: 0.1421 - accuracy: 0.9515 - val_loss: 1.0070 - val_accuracy: 0.7500

# %%
# plot model performance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
scores = model.evaluate(test_data)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 39/39 [==============================] - 9s 229ms/step - loss: 0.5709 - accuracy: 0.8718
#
# accuracy: 87.18%
