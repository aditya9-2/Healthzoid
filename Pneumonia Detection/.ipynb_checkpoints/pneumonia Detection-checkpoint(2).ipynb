# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense
from tensorflow.keras import backend as K

import os
import numpy as np
import pandas as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img_name = 'NORMAL2-IM-0588-0001.jpeg'
img_normal = load_img('chest_xray/train/NORMAL/' + img_name)

print('NORMAL')
plt.imshow(img_normal)
plt.show()
# Out:
# NORMAL

# %%
img_name = 'person63_bacteria_306.jpeg'
img_pneumonia = load_img('chest_xray/train/PNEUMONIA/' + img_name)

print('PNEUMONIA')
plt.imshow(img_pneumonia)
plt.show()
# Out:
# PNEUMONIA

# %%
# dimensions of our images.
img_width, img_height = 150, 150

# %%
train_data_dir = 'chest_xray/train'
validation_data_dir = 'chest_xray/val'
test_data_dir = 'chest_xray/test'

nb_train_samples = 5217
nb_validation_samples = 17
epochs = 11
batch_size = 16

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

# %% [markdown]
# Create Sequential model

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %% [markdown]
# Check information about model

# %%
model.layers
# Out:
# [<keras.layers.convolutional.conv2d.Conv2D at 0x24599900700>,
#  <keras.layers.core.activation.Activation at 0x24599d2c0a0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x24599d2fdc0>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2459be9c4f0>,
#  <keras.layers.core.activation.Activation at 0x2459be9d1e0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x2459be9de40>,
#  <keras.layers.convolutional.conv2d.Conv2D at 0x2459be9ea40>,
#  <keras.layers.core.activation.Activation at 0x2459be9f5b0>,
#  <keras.layers.pooling.max_pooling2d.MaxPooling2D at 0x2459be9fcd0>,
#  <keras.layers.reshaping.flatten.Flatten at 0x2459be9fd00>,
#  <keras.layers.core.dense.Dense at 0x2459be9fc70>,
#  <keras.layers.core.activation.Activation at 0x2459bef1720>,
#  <keras.layers.regularization.dropout.Dropout at 0x2459be9ead0>,
#  <keras.layers.core.dense.Dense at 0x2459bef2350>,
#  <keras.layers.core.activation.Activation at 0x2459bef2a70>]

# %%
model.input
# Out:
# <KerasTensor: shape=(None, 150, 150, 3) dtype=float32 (created by layer 'conv2d_input')>

# %%
model.output
# Out:
# <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'activation_4')>

# %% [markdown]
# Compile

# %%
model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %% [markdown]
# Uploading Image

# %%
# this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True)

# %%
# this is the augmentation configuration we will use for testing:
# only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

# %%
train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 5216 images belonging to 2 classes.

# %%
validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 16 images belonging to 2 classes.

# %%
test_generator = test_datagen.flow_from_directory(
    test_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')
# Out:
# Found 624 images belonging to 2 classes.

# %% [markdown]
# Fit Model

# %%
history = model.fit(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# Epoch 1/11
# 326/326 [==============================] - 118s 360ms/step - loss: 0.4180 - accuracy: 0.8263 - val_loss: 0.6608 - val_accuracy: 0.8125
# Epoch 2/11
# 326/326 [==============================] - 131s 401ms/step - loss: 0.2795 - accuracy: 0.8926 - val_loss: 0.7223 - val_accuracy: 0.6875
# Epoch 3/11
# 326/326 [==============================] - 124s 380ms/step - loss: 0.2282 - accuracy: 0.9126 - val_loss: 0.7829 - val_accuracy: 0.6875
# Epoch 4/11
# 326/326 [==============================] - 119s 364ms/step - loss: 0.2228 - accuracy: 0.9158 - val_loss: 0.4103 - val_accuracy: 0.8750
# Epoch 5/11
# 326/326 [==============================] - 125s 382ms/step - loss: 0.1909 - accuracy: 0.9296 - val_loss: 1.5012 - val_accuracy: 0.6250
# Epoch 6/11
# 326/326 [==============================] - 121s 372ms/step - loss: 0.1905 - accuracy: 0.9339 - val_loss: 0.4268 - val_accuracy: 0.8125
# Epoch 7/11
# 326/326 [==============================] - 123s 376ms/step - loss: 0.1805 - accuracy: 0.9363 - val_loss: 0.9837 - val_accuracy: 0.6250
# Epoch 8/11
# 326/326 [==============================] - 119s 364ms/step - loss: 0.1748 - accuracy: 0.9348 - val_loss: 0.7728 - val_accuracy: 0.6250
# Epoch 9/11
# 326/326 [==============================] - 124s 381ms/step - loss: 0.1631 - accuracy: 0.9423 - val_loss: 0.7847 - val_accuracy: 0.7500
# Epoch 10/11
# 326/326 [==============================] - 119s 366ms/step - loss: 0.1529 - accuracy: 0.9461 - val_loss: 1.5857 - val_accuracy: 0.6250
# Epoch 11/11
# 326/326 [==============================] - 121s 371ms/step - loss: 0.1524 - accuracy: 0.9465 - val_loss: 1.6668 - val_accuracy: 0.6875

# %%
# plot model performance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
model.save('pneumonia_model.h5')

# %%
# evaluate the model
scores = model.evaluate(test_generator)
print("\n%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
# Out:
# 39/39 [==============================] - 6s 145ms/step - loss: 0.8365 - accuracy: 0.7965
#
# accuracy: 79.65%
